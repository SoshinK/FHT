# %%
import numpy as np
import cv2 as cv
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import fht

# %% [markdown]
# ### Исходное изображение- пучок прямых

# %%
img1 = cv.imread("./img/bundle.png")
plt.imshow(img1)

# %% [markdown]
# ### Хаф-образ для вертикальных-правых прямых

# %%
plt.imshow(fht.FHT(img1, direction='vr'))

# %% [markdown]
# ### Хаф-образ для вертикальных-левых прямых

# %%
plt.imshow(fht.FHT(img1, direction='vl'))

# %% [markdown]
# ### Хаф-образ для горизонтальных-верхних прямых

# %%
plt.imshow(fht.FHT(img1, direction='hu'))

# %% [markdown]
# ### Хаф-образ для горизонтальных-нижних прямых

# %%
plt.imshow(fht.FHT(img1, direction='hd'))

# %% [markdown]
# ### Хаф-образ для всех наклонов.
#
# Слева-направо: вертикальные-левые, вертикальные-правые, горизонтльные-нижние, горизонтльные-верхние.

# %%
plt.imshow(fht.FHT(img1))

# %% [markdown]
# ### Демонстрация обнаржуения прямых. draw_diadlns и hough_getlines

# %%
color = (193, 0, 32)

# %% [markdown]
# Выделим три прямых:

# %%
canvas = fht.draw_diadlns(img1, fht.hough_getlines(img1, 3), color)
plt.imshow(canvas)

# %% [markdown]
# Теперь выделим границы прямоугольника:

# %%
img2 = cv.imread("./img/qqq.png")
canvas = fht.draw_diadlns(img2, fht.hough_getlines(img2, 3), color)
plt.imshow(canvas)

# %% [markdown]
# Картинка из интернета с кроссвордом. Выделим 8 прямых:

# %%
img3 = cv.imread("./img/newspaper.png")
canvas = fht.draw_diadlns(img3, fht.hough_getlines(img3, 8), color)
plt.imshow(canvas)
